# %%
! pip install selenium

# %%
from urllib.request import urlopen
from urllib.error import HTTPError
from bs4 import BeautifulSoup
import pandas as pd
# MAC
#import ssl
#ssl._create_default_https_context = ssl._create_unverified_context
# create dataframe

# %%
from selenium import webdriver
from selenium.common.exceptions import NoSuchElementException
from selenium.webdriver.common.keys import Keys
import time
import pandas as pd

# %%
driver = webdriver.Chrome('C:/Users/kehua/chromedriver.exe')
url = 'https://www.rakuya.com.tw/realprice/result?city=0&closedate=1y&sort=11&page=3'
driver.get(url)

# %%
df = pd.DataFrame(columns=["日期", "地址", "類別","格局","年齡","坪數","每坪價格","賣價"])

# %%
page = [2-383]
while True:
    url = "https://www.rakuya.com.tw/realprice/result?city=0&closedate=1y&sort=11&page=" + str(page)
    print("正在處理頁面:", url)
    try:
        response = urlopen(url)
    except HTTPError:
        print("大概是結束了")
        break
         soup = BeautifulSoup(response)

# %%
   

    soup = BeautifulSoup(driver.page_source,'html.parser')
    houserealprice = soup.find_all("li",{"class":"obj"})
    for hrp in houserealprice:
         date = hrp.find("span").text
         address = hrp.find("h2").text
         Type = hrp.find("span", class_="tType").text
         tLayout = hrp.find("span", class_="tLayout").text
         tAge = hrp.find("span", class_="tAge").text
         tPing = hrp.find("span", class_="tPing").text
         tPprice = hrp.find("span", class_="tPprice").text
         tTprice = hrp.find("span", class_="tTprice").text
         tDetail = hrp.find("span", class_="tDetail").text
         #driver.find_element_by_link_text('Next')
         #print(date,address,Type,tLayout,tAge,tPing,tPprice,tTprice,tDetail)
         s = pd.Series([date, address, Type,tLayout,tAge,tPing,tPprice,tTprice,tDetail],
                           index=["日期", "地址", "類別","格局","年齡","坪數","每坪價格","賣價","細節"])
         df = df.append(s, ignore_index=True)
    #page = page + 1     
     
#df.to_csv("houserealprice.csv", encoding="utf-8", index=False)

# %%
df
# Out:
#              日期                      地址       類別      格局     年齡        坪數  \
# 0   2019/05特殊交易   台北市大安區建國南路一段279巷1~30號  電梯大廈/華廈  1房1廳1衛  32.9年     12.8坪
# 1       2019/05     台北市大安區大安路二段3巷31~60號      純車位  0房0廳0衛   1.6年     9.71坪
# 2       2019/05   台北市信義區和段一小段331~360地號      純土地       -      -    13.48坪
# 3       2019/05     台北市松山區復興北路427巷1~30號      純車位  0房0廳0衛  10.9年     3.47坪
# 4       2019/05          台北市北投區振興街1~30號      純車位  0房0廳0衛      -    14.08坪
# 5   2019/05特殊交易    台北市北投區中和街502巷8弄1~30號       公寓  3房2廳1衛  40.7年    28.93坪
# 6   2019/05特殊交易       台北市內湖區金湖路46巷1~30號  電梯大廈/華廈  3房1廳1衛  20.8年     33.2坪
# 7   2019/05特殊交易    台北市松山區延壽街356巷4弄1~30號       公寓  3房2廳1衛  41.5年     33.6坪
# 8   2019/05特殊交易     台北市內湖區內湖路三段331~360號      純車位  0房0廳0衛      -    10.03坪
# 9   2019/05特殊交易      台北市中山區新生北路二段31~60號  電梯大廈/華廈  2房1廳1衛  23.4年    20.22坪
# 10      2019/05        台北市萬華區長沙街二段1~30號       套房  1房1廳1衛  39.3年    10.84坪
# 11  2019/05特殊交易    台北市大安區信義路四段335巷1~30號      純車位  0房0廳0衛  11.7年    14.51坪
# 12      2019/05    台北市中山區林森北路119巷31~60號       公寓  3房2廳2衛      -    29.32坪
# 13      2019/05  台北市文山區木新路三段232巷7弄1~30號      純車位  0房0廳0衛  12.6年     9.18坪
# 14      2019/05     台北市南港區南港路二段38巷1~30號      純車位  0房0廳0衛  10.5年    14.08坪
# 15      2019/05   台北市士林區德行東路358巷2弄1~30號       公寓  0房0廳0衛  31.6年     7.52坪
# 16      2019/05   台北市北投區豐年段三小段331~360地號      純土地       -      -   372.44坪
# 17  2019/05特殊交易   台北市南港區南港段三小段241~270地號      純土地       -      -   131.89坪
# 18  2019/05特殊交易   台北市南港區南港段三小段211~240地號      純土地       -      -   185.13坪
